# %%
from classifier import *
decision_tree()
# Out:
# ========= Decision Tree =========
# train data: dataset1-7000.csv
# test data: dataset2-3000.csv
# Accuracy with Decidion Tree: 93.77%
# Success.

# %%
naive_bayes()
# Out:
# ========= Naive Bayes =========
# train data: dataset1-7000.csv
# test data: dataset2-3000.csv
# Accuracy with Gaussian Naive Bayes: 90.50%
# Success.

# %%
svm()
# Out:
# ============ SVM =============
# train data: dataset1-7000.csv
# test data: dataset2-3000.csv
# Accuracy on test data with SVM: 94.00%
# Success.

# %%
knn()
# Out:
# ============ KNN ===========
# train data: dataset1-7000.csv
# test data: dataset2-3000.csv
# Accuracy on test data with KNN: 93.67%
# Success.
